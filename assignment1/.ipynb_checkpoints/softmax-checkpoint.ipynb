# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.305966
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Sanity check for cross-entropy loss is -log(1/num_classes), here num_classes=10*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.967774 analytic: 0.967774, relative error: 4.922223e-09
# numerical: -1.747439 analytic: -1.747439, relative error: 8.405983e-09
# numerical: -0.483817 analytic: -0.483817, relative error: 2.639288e-09
# numerical: 0.482459 analytic: 0.482459, relative error: 6.912791e-08
# numerical: 1.234388 analytic: 1.234388, relative error: 1.165556e-08
# numerical: -0.083302 analytic: -0.083302, relative error: 4.500570e-07
# numerical: 0.712177 analytic: 0.712177, relative error: 8.629607e-08
# numerical: -0.080603 analytic: -0.080603, relative error: 8.154523e-07
# numerical: -1.984023 analytic: -1.984023, relative error: 2.934111e-09
# numerical: -4.865274 analytic: -4.865274, relative error: 1.522141e-09
# numerical: 3.623232 analytic: 3.623255, relative error: 3.095779e-06
# numerical: -0.329178 analytic: -0.329166, relative error: 1.782053e-05
# numerical: -0.428990 analytic: -0.428991, relative error: 1.770921e-06
# numerical: 2.646003 analytic: 2.646044, relative error: 7.771765e-06
# numerical: 2.823641 analytic: 2.823691, relative error: 8.944867e-06
# numerical: -1.431937 analytic: -1.431946, relative error: 3.439182e-06
# numerical: -0.865765 analytic: -0.865751, relative error: 7.709370e-06
# numerical: 1.864685 analytic: 1.864710, relative error: 6.879351e-06
# numerical: 0.857266 analytic: 0.857263, relative error: 1.955862e-06
# numerical: -1.620241 analytic: -1.620272, relative error: 9.562138e-06

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.305966e+00 computed in 0.195172s
# (500, 10)
# vectorized loss: 2.305966e+00 computed in 0.019719s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = np.exp(np.random.randint(-15,high=-6,size=(4,))) # log search
regularization_strengths = np.exp(np.random.randint(1,high=4,size=(5,))) #log search
# print(learning_rates)
# print(regularization_strengths)
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for learning_rate in learning_rates:
#     break
    for regularization_strength in regularization_strengths:
        softmax = Softmax()
        softmax.train(X_train,y_train,
                      learning_rate=learning_rate,reg=regularization_strength,
                      num_iters=1500,verbose=True)
        train_pred = softmax.predict(X_train)
        train_acc = np.mean(train_pred == y_train)
        val_pred = softmax.predict(X_val)
        val_acc = np.mean(val_pred == y_val)
        if val_acc > best_val: 
            best_val = val_acc
            best_softmax = softmax
        print("train accuracy=",train_acc,"validation accuracy=",val_acc)
        results[(learning_rate,regularization_strength)] = (train_acc,val_acc)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 5.541376
# iteration 100 / 1500: loss 3.234781
# iteration 200 / 1500: loss 3.047287
# iteration 300 / 1500: loss 2.809010
# iteration 400 / 1500: loss 2.846551
# iteration 500 / 1500: loss 2.437820
# iteration 600 / 1500: loss 2.680656
# iteration 700 / 1500: loss 2.376600
# iteration 800 / 1500: loss 2.382564
# iteration 900 / 1500: loss 2.576258
# iteration 1000 / 1500: loss 2.375710
# iteration 1100 / 1500: loss 2.608856
# iteration 1200 / 1500: loss 2.388185
# iteration 1300 / 1500: loss 2.287252
# iteration 1400 / 1500: loss 2.326787
# train accuracy= 0.30112244898 validation accuracy= 0.298
# iteration 0 / 1500: loss 6.197928
# iteration 100 / 1500: loss 3.745296
# iteration 200 / 1500: loss 3.320900
# iteration 300 / 1500: loss 2.929968
# iteration 400 / 1500: loss 2.722583
# iteration 500 / 1500: loss 3.082198
# iteration 600 / 1500: loss 2.644889
# iteration 700 / 1500: loss 2.872543
# iteration 800 / 1500: loss 2.725706
# iteration 900 / 1500: loss 2.725661
# iteration 1000 / 1500: loss 2.533038
# iteration 1100 / 1500: loss 2.671217
# iteration 1200 / 1500: loss 2.653058
# iteration 1300 / 1500: loss 2.472672
# iteration 1400 / 1500: loss 2.379775
# train accuracy= 0.296142857143 validation accuracy= 0.313
# iteration 0 / 1500: loss 6.934158
# iteration 100 / 1500: loss 3.586237
# iteration 200 / 1500: loss 3.120855
# iteration 300 / 1500: loss 3.196819
# iteration 400 / 1500: loss 2.818246
# iteration 500 / 1500: loss 2.936453
# iteration 600 / 1500: loss 3.113513
# iteration 700 / 1500: loss 2.897122
# iteration 800 / 1500: loss 2.670029
# iteration 900 / 1500: loss 2.661715
# iteration 1000 / 1500: loss 2.750069
# iteration 1100 / 1500: loss 2.521634
# iteration 1200 / 1500: loss 2.449509
# iteration 1300 / 1500: loss 2.358700
# iteration 1400 / 1500: loss 2.651938
# train accuracy= 0.300265306122 validation accuracy= 0.3
# iteration 0 / 1500: loss 5.109007
# iteration 100 / 1500: loss 3.587134
# iteration 200 / 1500: loss 2.884519
# iteration 300 / 1500: loss 2.991491
# iteration 400 / 1500: loss 2.613752
# iteration 500 / 1500: loss 2.501986
# iteration 600 / 1500: loss 2.636780
# iteration 700 / 1500: loss 2.676838
# iteration 800 / 1500: loss 2.427617
# iteration 900 / 1500: loss 2.347904
# iteration 1000 / 1500: loss 2.366208
# iteration 1100 / 1500: loss 2.500300
# iteration 1200 / 1500: loss 2.267267
# iteration 1300 / 1500: loss 2.299559
# iteration 1400 / 1500: loss 2.186678
# train accuracy= 0.294571428571 validation accuracy= 0.286
# iteration 0 / 1500: loss 5.970373
# iteration 100 / 1500: loss 3.609727
# iteration 200 / 1500: loss 3.163177
# iteration 300 / 1500: loss 3.027038
# iteration 400 / 1500: loss 2.847509
# iteration 500 / 1500: loss 2.713632
# iteration 600 / 1500: loss 2.572783
# iteration 700 / 1500: loss 2.536490
# iteration 800 / 1500: loss 2.665372
# iteration 900 / 1500: loss 2.359932
# iteration 1000 / 1500: loss 2.386617
# iteration 1100 / 1500: loss 2.409291
# iteration 1200 / 1500: loss 2.557040
# iteration 1300 / 1500: loss 2.459318
# iteration 1400 / 1500: loss 2.313119
# train accuracy= 0.298 validation accuracy= 0.32
# iteration 0 / 1500: loss 5.588103
# iteration 100 / 1500: loss 3.223511
# iteration 200 / 1500: loss 2.970350
# iteration 300 / 1500: loss 2.925905
# iteration 400 / 1500: loss 2.803024
# iteration 500 / 1500: loss 2.635813
# iteration 600 / 1500: loss 2.530146
# iteration 700 / 1500: loss 2.649372
# iteration 800 / 1500: loss 2.257263
# iteration 900 / 1500: loss 2.427553
# iteration 1000 / 1500: loss 2.514536
# iteration 1100 / 1500: loss 2.411949
# iteration 1200 / 1500: loss 2.362019
# iteration 1300 / 1500: loss 2.520429
# iteration 1400 / 1500: loss 2.262415
# train accuracy= 0.292040816327 validation accuracy= 0.266
# iteration 0 / 1500: loss 6.458527
# iteration 100 / 1500: loss 3.485657
# iteration 200 / 1500: loss 3.509239
# iteration 300 / 1500: loss 3.190965
# iteration 400 / 1500: loss 3.092562
# iteration 500 / 1500: loss 2.887750
# iteration 600 / 1500: loss 3.059380
# iteration 700 / 1500: loss 2.726226
# iteration 800 / 1500: loss 2.470304
# iteration 900 / 1500: loss 2.677295
# iteration 1000 / 1500: loss 2.704746
# iteration 1100 / 1500: loss 2.593996
# iteration 1200 / 1500: loss 2.525734
# iteration 1300 / 1500: loss 2.597522
# iteration 1400 / 1500: loss 2.535192
# train accuracy= 0.298244897959 validation accuracy= 0.305
# iteration 0 / 1500: loss 6.593295
# iteration 100 / 1500: loss 4.136017
# iteration 200 / 1500: loss 3.131483
# iteration 300 / 1500: loss 3.058502
# iteration 400 / 1500: loss 3.029063
# iteration 500 / 1500: loss 2.999770
# iteration 600 / 1500: loss 2.837222
# iteration 700 / 1500: loss 2.844094
# iteration 800 / 1500: loss 2.757991
# iteration 900 / 1500: loss 2.645758
# iteration 1000 / 1500: loss 2.708142
# iteration 1100 / 1500: loss 2.575799
# iteration 1200 / 1500: loss 2.486917
# iteration 1300 / 1500: loss 2.678790
# iteration 1400 / 1500: loss 2.685778
# train accuracy= 0.295693877551 validation accuracy= 0.306
# iteration 0 / 1500: loss 5.388955
# iteration 100 / 1500: loss 3.552963
# iteration 200 / 1500: loss 3.104005
# iteration 300 / 1500: loss 2.767847
# iteration 400 / 1500: loss 2.697968
# iteration 500 / 1500: loss 2.542140
# iteration 600 / 1500: loss 2.713369
# iteration 700 / 1500: loss 2.626759
# iteration 800 / 1500: loss 2.405398
# iteration 900 / 1500: loss 2.510216
# iteration 1000 / 1500: loss 2.426437
# iteration 1100 / 1500: loss 2.327429
# iteration 1200 / 1500: loss 2.367830
# iteration 1300 / 1500: loss 2.268327
# iteration 1400 / 1500: loss 2.313543
# train accuracy= 0.296285714286 validation accuracy= 0.297
# iteration 0 / 1500: loss 4.394832
# iteration 100 / 1500: loss 3.378217
# iteration 200 / 1500: loss 3.243894
# iteration 300 / 1500: loss 2.804323
# iteration 400 / 1500: loss 3.146336
# iteration 500 / 1500: loss 2.764764
# iteration 600 / 1500: loss 2.780530
# iteration 700 / 1500: loss 2.428946
# iteration 800 / 1500: loss 2.551548
# iteration 900 / 1500: loss 2.347273
# iteration 1000 / 1500: loss 2.439026
# iteration 1100 / 1500: loss 2.427048
# iteration 1200 / 1500: loss 2.394389
# iteration 1300 / 1500: loss 2.331492
# iteration 1400 / 1500: loss 2.282926
# train accuracy= 0.295551020408 validation accuracy= 0.294
# iteration 0 / 1500: loss 6.107213
# iteration 100 / 1500: loss 35.632070
# iteration 200 / 1500: loss 42.319665
# iteration 300 / 1500: loss 23.601734
# iteration 400 / 1500: loss 41.572604
# iteration 500 / 1500: loss 36.701332
# iteration 600 / 1500: loss 41.836928
# iteration 700 / 1500: loss 33.146244
# iteration 800 / 1500: loss 29.036773
# iteration 900 / 1500: loss 41.023716
# iteration 1000 / 1500: loss 43.403178
# iteration 1100 / 1500: loss 37.298522
# iteration 1200 / 1500: loss 30.150545
# iteration 1300 / 1500: loss 36.187552
# iteration 1400 / 1500: loss 40.863918
# train accuracy= 0.351326530612 validation accuracy= 0.333
# iteration 0 / 1500: loss 5.602750
# iteration 100 / 1500: loss 41.351728
# iteration 200 / 1500: loss 36.511743
# iteration 300 / 1500: loss 48.275988
# iteration 400 / 1500: loss 22.248233
# iteration 500 / 1500: loss 37.310125
# iteration 600 / 1500: loss 47.268987
# iteration 700 / 1500: loss 37.607398
# iteration 800 / 1500: loss 31.997172
# iteration 900 / 1500: loss 38.029652
# iteration 1000 / 1500: loss 33.865427
# iteration 1100 / 1500: loss 41.129185
# iteration 1200 / 1500: loss 24.730240
# iteration 1300 / 1500: loss 41.764499
# iteration 1400 / 1500: loss 30.104461
# train accuracy= 0.29612244898 validation accuracy= 0.267
# iteration 0 / 1500: loss 5.209235
# iteration 100 / 1500: loss 32.609155
# iteration 200 / 1500: loss 40.621205
# iteration 300 / 1500: loss 27.454134
# iteration 400 / 1500: loss 39.186063
# iteration 500 / 1500: loss 43.938982
# iteration 600 / 1500: loss 32.730941
# iteration 700 / 1500: loss 34.282982
# iteration 800 / 1500: loss 32.855174
# iteration 900 / 1500: loss 33.002423
# iteration 1000 / 1500: loss 53.466443
# iteration 1100 / 1500: loss 51.612208
# iteration 1200 / 1500: loss 51.028109
# iteration 1300 / 1500: loss 26.195002
# iteration 1400 / 1500: loss 38.254197
# train accuracy= 0.338795918367 validation accuracy= 0.307
# iteration 0 / 1500: loss 6.766629
# iteration 100 / 1500: loss 24.325460
# iteration 200 / 1500: loss 28.129453
# iteration 300 / 1500: loss 45.118979
# iteration 400 / 1500: loss 45.717039
# iteration 500 / 1500: loss 30.784168
# iteration 600 / 1500: loss 44.306871
# iteration 700 / 1500: loss 43.830654
# iteration 800 / 1500: loss 29.812928
# iteration 900 / 1500: loss 24.493269
# iteration 1000 / 1500: loss 51.283786
# iteration 1100 / 1500: loss 31.924915
# iteration 1200 / 1500: loss 29.894994
# iteration 1300 / 1500: loss 23.752527
# iteration 1400 / 1500: loss 31.999184
# train accuracy= 0.290224489796 validation accuracy= 0.288
# iteration 0 / 1500: loss 6.331236
# iteration 100 / 1500: loss 35.560461
# iteration 200 / 1500: loss 45.372841
# iteration 300 / 1500: loss 26.494202
# iteration 400 / 1500: loss 25.736531
# iteration 500 / 1500: loss 28.637432
# iteration 600 / 1500: loss 53.263158
# iteration 700 / 1500: loss 30.777113
# iteration 800 / 1500: loss 29.074131
# iteration 900 / 1500: loss 20.455803
# iteration 1000 / 1500: loss 30.786045
# iteration 1100 / 1500: loss 36.033439
# iteration 1200 / 1500: loss 40.198382
# iteration 1300 / 1500: loss 46.580752
# iteration 1400 / 1500: loss 24.490603
# train accuracy= 0.303571428571 validation accuracy= 0.297
# iteration 0 / 1500: loss 5.944992
# iteration 100 / 1500: loss 2.582943
# iteration 200 / 1500: loss 2.191768
# iteration 300 / 1500: loss 2.211287
# iteration 400 / 1500: loss 2.263650
# iteration 500 / 1500: loss 2.148643
# iteration 600 / 1500: loss 2.086979
# iteration 700 / 1500: loss 2.130193
# iteration 800 / 1500: loss 2.167940
# iteration 900 / 1500: loss 2.321348
# iteration 1000 / 1500: loss 1.899495
# iteration 1100 / 1500: loss 2.043639
# iteration 1200 / 1500: loss 1.873035
# iteration 1300 / 1500: loss 2.076181
# iteration 1400 / 1500: loss 2.026401
# train accuracy= 0.373265306122 validation accuracy= 0.362
# iteration 0 / 1500: loss 5.892448
# iteration 100 / 1500: loss 2.729064
# iteration 200 / 1500: loss 2.669025
# iteration 300 / 1500: loss 2.689621
# iteration 400 / 1500: loss 2.276583
# iteration 500 / 1500: loss 2.442059
# iteration 600 / 1500: loss 2.012677
# iteration 700 / 1500: loss 2.190966
# iteration 800 / 1500: loss 2.229843
# iteration 900 / 1500: loss 2.281146
# iteration 1000 / 1500: loss 2.059020
# iteration 1100 / 1500: loss 2.138440
# iteration 1200 / 1500: loss 2.198074
# iteration 1300 / 1500: loss 2.052404
# iteration 1400 / 1500: loss 2.064745
# train accuracy= 0.380816326531 validation accuracy= 0.36
# iteration 0 / 1500: loss 5.616561
# iteration 100 / 1500: loss 3.015787
# iteration 200 / 1500: loss 2.437069
# iteration 300 / 1500: loss 2.370471
# iteration 400 / 1500: loss 2.301151
# iteration 500 / 1500: loss 2.323410
# iteration 600 / 1500: loss 2.256037
# iteration 700 / 1500: loss 2.150389
# iteration 800 / 1500: loss 2.066050
# iteration 900 / 1500: loss 2.053400
# iteration 1000 / 1500: loss 2.064924
# iteration 1100 / 1500: loss 2.088461
# iteration 1200 / 1500: loss 2.024142
# iteration 1300 / 1500: loss 2.066670
# iteration 1400 / 1500: loss 2.090559
# train accuracy= 0.371857142857 validation accuracy= 0.363
# iteration 0 / 1500: loss 5.910692
# iteration 100 / 1500: loss 2.514538
# iteration 200 / 1500: loss 2.410769
# iteration 300 / 1500: loss 2.430534
# iteration 400 / 1500: loss 2.091525
# iteration 500 / 1500: loss 2.031882
# iteration 600 / 1500: loss 2.001197
# iteration 700 / 1500: loss 1.932589
# iteration 800 / 1500: loss 1.853197
# iteration 900 / 1500: loss 1.919077
# iteration 1000 / 1500: loss 1.897900
# iteration 1100 / 1500: loss 2.062858
# iteration 1200 / 1500: loss 1.902332
# iteration 1300 / 1500: loss 1.858252
# iteration 1400 / 1500: loss 1.804481
# train accuracy= 0.377183673469 validation accuracy= 0.374
# iteration 0 / 1500: loss 5.830867
# iteration 100 / 1500: loss 2.500050
# iteration 200 / 1500: loss 2.453167
# iteration 300 / 1500: loss 2.092392
# iteration 400 / 1500: loss 2.192785
# iteration 500 / 1500: loss 1.989920
# iteration 600 / 1500: loss 2.135169
# iteration 700 / 1500: loss 2.107230
# iteration 800 / 1500: loss 2.097643
# iteration 900 / 1500: loss 2.169049
# iteration 1000 / 1500: loss 1.902379
# iteration 1100 / 1500: loss 1.994352
# iteration 1200 / 1500: loss 1.919964
# iteration 1300 / 1500: loss 1.946044
# iteration 1400 / 1500: loss 1.776138
# train accuracy= 0.379489795918 validation accuracy= 0.372
# lr 3.059023e-07 reg 2.718282e+00 train accuracy: 0.296286 val accuracy: 0.297000
# lr 3.059023e-07 reg 7.389056e+00 train accuracy: 0.295551 val accuracy: 0.294000
# lr 3.059023e-07 reg 2.008554e+01 train accuracy: 0.295694 val accuracy: 0.306000
# lr 2.260329e-06 reg 2.718282e+00 train accuracy: 0.377184 val accuracy: 0.374000
# lr 2.260329e-06 reg 7.389056e+00 train accuracy: 0.379490 val accuracy: 0.372000
# lr 2.260329e-06 reg 2.008554e+01 train accuracy: 0.371857 val accuracy: 0.363000
# lr 1.234098e-04 reg 2.718282e+00 train accuracy: 0.290224 val accuracy: 0.288000
# lr 1.234098e-04 reg 7.389056e+00 train accuracy: 0.303571 val accuracy: 0.297000
# lr 1.234098e-04 reg 2.008554e+01 train accuracy: 0.338796 val accuracy: 0.307000
# best validation accuracy achieved during cross-validation: 0.374000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.341000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
